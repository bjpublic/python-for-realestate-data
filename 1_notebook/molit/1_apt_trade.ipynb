# %% [markdown]
# ## 아파트 실거래가 데이터 수집

# %%
import pandas as pd
import requests
import os
from bs4 import BeautifulSoup as bs

os.chdir("/home/ubuntu/real_estate_dashboard")
print(os.getcwd())
# Out:
# /home/ubuntu/real_estate_dashboard

# %%
df = pd.read_csv("0_data/legal_info.csv")

# 생성한 법정동 코드 고유값 지정
LAWD_CD_list = df['법정동시군구코드'].unique()

# %%
# API키 세팅
api_key = '발급받은 API키'


column_nm = ['거래금액', '거래유형', '건축년도', '년', '도로명', '도로명건물본번호코드', '도로명건물부번호코드', 
             '도로명시군구코드', '도로명일련번호코드', '도로명지상지하코드', '도로명코드', '법정동', '법정동본번코드', 
             '법정동부번코드', '법정동시군구코드', '법정동읍면동코드', '법정동지번코드', '아파트',
             '월', '일', '일련번호', '전용면적', '중개사소재지', '지번', '지역코드', '층']

# %%
# 서비스 URL
url = "http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev"

year_month_key = "202101"

# 요청변수 파라미터 설정     
params = "?" + \
        "ServiceKey=" + api_key + "&" + \
        "pageNo=" + "1" + "&" + \
        "numOfRows=" + "9999" + "&" + \
        "LAWD_CD=" + "11110" + "&" + \
        "DEAL_YMD=" + year_month_key

# %%
# requests, BeautifulSoup 라이브러리를 사용한 데이터 수집
res = requests.get(url + params)
soup = bs(res.text, 'xml')
items = soup.find_all('item')

# %%
total = pd.DataFrame()
# 수집된 데이터를 Pandas 데이터 프레임 형식으로 변환
for k in range(len(items)):
    df_raw = []
    for j in column_nm:
        df_raw.append(items[k].find(j).text)
    df = pd.DataFrame(df_raw).T
    total = pd.concat([total, df])

total.columns = column_nm

total.head().T
# Out:
#                      0               0           0           0           0
# 거래금액           130,000         150,000     175,000     175,000     180,000
# 거래유형
# 건축년도              2000            2008        2004        2004        2004
# 년                 2021            2021        2021        2021        2021
# 도로명            자하문로33길            경희궁길       사직로8길       사직로8길       사직로8길
# 도로명건물본번호코드       00043           00057       00024       00024       00034
# 도로명건물부번호코드       00000           00000       00000       00000       00000
# 도로명시군구코드         11110           11110       11110       11110       11110
# 도로명일련번호코드           01              01          05          05          05
# 도로명지상지하코드            0               0           0           0           0
# 도로명코드          4100285         4100010     4100135     4100135     4100135
# 법정동                청운동             사직동         내수동         내수동         내수동
# 법정동본번코드           0056            0009        0071        0071        0072
# 법정동부번코드           0045            0001        0000        0000        0000
# 법정동시군구코드         11110           11110       11110       11110       11110
# 법정동읍면동코드         10100           11500       11800       11800       11800
# 법정동지번코드              1               1           1           1           1
# 아파트               청운현대  광화문스페이스본(106동)   경희궁의아침2단지   경희궁의아침2단지   경희궁의아침3단지
# 월                    1               1           1           1           1
# 일                   14               7          15          15          17
# 일련번호           11110-4      11110-2204   11110-115   11110-115   11110-116
# 전용면적            129.76          144.52      174.55      174.55      123.13
# 중개사소재지
# 지번               56-45             9-1          71          71          72
# 지역코드             11110           11110       11110       11110       11110
# 층                    2               6           4           4          13

# %% [markdown]
# # 법정동 코드를 사용한 전체 데이터 반복문 사용

# %%
import pandas as pd
import requests
import os
from bs4 import BeautifulSoup as bs

os.chdir("/home/ubuntu/real_estate_dashboard")
print(os.getcwd())

df = pd.read_csv("0_data/legal_info.csv")

# 생성한 법정동 코드 고유값 지정
LAWD_CD_list = df['법정동시군구코드'].unique()


# API키 세팅
api_key = '발급받은 API키'

column_nm = ['거래금액', '거래유형', '건축년도', '년', '도로명', '도로명건물본번호코드', '도로명건물부번호코드', 
             '도로명시군구코드', '도로명일련번호코드', '도로명지상지하코드', '도로명코드', '법정동', '법정동본번코드', 
             '법정동부번코드', '법정동시군구코드', '법정동읍면동코드', '법정동지번코드', '아파트',
             '월', '일', '일련번호', '전용면적', '중개사소재지', '지번', '지역코드', '층']

for i in range(len(LAWD_CD_list)):
    
    # 서비스 URL
    url = "http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev"

    year_month_key = "202101"
    
    # 요청변수 파라미터 설정     
    params = "?" + \
            "ServiceKey=" + api_key + "&" + \
            "pageNo=" + "1" + "&" + \
            "numOfRows=" + "9999" + "&" + \
            "LAWD_CD=" + str(LAWD_CD_list[i])  + "&" + \
            "DEAL_YMD=" + year_month_key

    # requests, BeautifulSoup 라이브러리를 사용한 데이터 수집
    res = requests.get(url + params)
    soup = bs(res.text, 'xml')
    items = soup.find_all('item')


    total = pd.DataFrame()
    # 수집된 데이터를 Pandas 데이터 프레임 형식으로 변환

    for k in range(len(items)):
        df_raw = []
        for j in column_nm:
            print(LAWD_CD_list[i],k,j) # 에러 파악 여부 
            df_raw.append(items[k].find(j).text)
        df = pd.DataFrame(df_raw).T
        total = pd.concat([total, df])

    total.columns = column_nm

total.head().T

# %% [markdown]
# ### 에러 해결

# %%
import pandas as pd
import requests
import os
from bs4 import BeautifulSoup as bs

os.chdir("/home/ubuntu/real_estate_dashboard")
print(os.getcwd())


df = pd.read_csv("../0_data/legal_info.csv")

# 생성한 법정동 코드 고유값 지정
LAWD_CD_list = df['법정동시군구코드'].unique()


# API키 세팅
api_key = '발급받은 API키'

column_nm = ['거래금액', '거래유형', '건축년도', '년', '도로명', '도로명건물본번호코드', '도로명건물부번호코드', 
             '도로명시군구코드', '도로명일련번호코드', '도로명지상지하코드', '도로명코드', '법정동', '법정동본번코드', 
             '법정동부번코드', '법정동시군구코드', '법정동읍면동코드', '법정동지번코드', '아파트',
             '월', '일', '일련번호', '전용면적', '중개사소재지', '지번', '지역코드', '층']

for i in range(len(LAWD_CD_list)):
    
    # 서비스 URL
    url = "http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev"

    year_month_key = "202101"
    
    # 요청변수 파라미터 설정     
    params = "?" + \
            "ServiceKey=" + api_key + "&" + \
            "pageNo=" + "1" + "&" + \
            "numOfRows=" + "9999" + "&" + \
            "LAWD_CD=" + str(LAWD_CD_list[i])  + "&" + \
            "DEAL_YMD=" + year_month_key

    # requests, BeautifulSoup 라이브러리를 사용한 데이터 수집
    res = requests.get(url + params)
    soup = bs(res.text, 'xml')
    items = soup.find_all('item')


    total = pd.DataFrame()
    # 수집된 데이터를 Pandas 데이터 프레임 형식으로 변환

    for k in range(len(items)):
        df_raw = []
        for j in column_nm:
            print(LAWD_CD_list[i],k,j) # 에러 파악 여부 
            df_raw.append(items[k].find(j).text)
        df = pd.DataFrame(df_raw).T
        total = pd.concat([total, df])

    total.columns = column_nm

# total.head().T
# Out:
#                      0           0           0           0           0
# 거래금액            92,000     120,000     150,500      70,000     145,000
# 거래유형              중개거래        중개거래        중개거래         직거래        중개거래
# 건축년도              2001        2001        2019        2001        2011
# 년                 2021        2021        2021        2021        2021
# 도로명              새창로8길        효창원로         백범로         새창로        효창원로
# 도로명건물본번호코드       00157       00017       00313       00070       00088
# 도로명건물부번호코드       00000       00000       00000       00000       00000
# 도로명시군구코드         11170       11170       11170       11170       11170
# 도로명일련번호코드           01          06          00          02          10
# 도로명지상지하코드            0           0     존재하지 않음           0           0
# 도로명코드          4106144     3005022     3005016     3005018     3005022
# 법정동                산천동         산천동         효창동         도원동         용문동
# 법정동본번코드           0204        0193        0287        0023        0090
# 법정동부번코드           0000        0000        0000        0000        0000
# 법정동시군구코드         11170       11170       11170       11170       11170
# 법정동읍면동코드         11500       11500       11900       12000       12100
# 법정동지번코드              1           1           1           1           1
# 아파트               한강타운       리버힐삼성  용산롯데캐슬센터포레       삼성래미안       브라운스톤
# 월                   12          12          12          12          12
# 일                    3           4           9          15          17
# 일련번호         11170-139   11170-138  11170-3209    11170-27  11170-2841
# 전용면적             59.69       59.55     59.8677       59.94       84.76
# 중개사소재지          서울 마포구      서울 용산구      서울 용산구                  서울 용산구
# 지번                 204         193         287          23          90
# 지역코드             11170       11170       11170       11170       11170
# 층                    5           6           5          12          10

# %% [markdown]
# ## 데이터 저장

# %%
directory = "0_data/apt_trade"
if not os.path.exists(directory):
    os.makedirs(directory)
    
file_name = '0_data/apt_trade/apt_trade_sample_' + '202101' + ".csv"
total.to_csv(file_name, index = False)

# %% [markdown]
# ## 최종 코드

# %%
import pandas as pd
import requests
import os
from bs4 import BeautifulSoup as bs

os.chdir("/home/ubuntu/real_estate_dashboard")
print(os.getcwd())

df = pd.read_csv("0_data/legal_info.csv")

# 생성한 법정동 코드 고유값 지정
LAWD_CD_list = df['법정동시군구코드'].unique()

# API키 세팅
api_key = '발급받은 API키'

column_nm = ['거래금액', '거래유형', '건축년도', '년', '도로명', '도로명건물본번호코드', '도로명건물부번호코드', 
             '도로명시군구코드', '도로명일련번호코드', '도로명지상지하코드', '도로명코드', '법정동', '법정동본번코드', 
             '법정동부번코드', '법정동시군구코드', '법정동읍면동코드', '법정동지번코드', '아파트',
             '월', '일', '일련번호', '전용면적', '중개사소재지', '지번', '지역코드', '층']

for i in range(len(LAWD_CD_list)):
    
    # 서비스 URL
    url = "http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev"

    year_month_key = "202101"
    
    # 요청변수 파라미터 설정     
    params = "?" + \
            "ServiceKey=" + api_key + "&" + \
            "pageNo=" + "1" + "&" + \
            "numOfRows=" + "9999" + "&" + \
            "LAWD_CD=" + str(LAWD_CD_list[i])  + "&" + \
            "DEAL_YMD=" + year_month_key   

    # requests, BeautifulSoup 라이브러리를 사용한 데이터 수집
    res = requests.get(url + params)
    soup = bs(res.text, 'xml')
    items = soup.find_all('item')


    total = pd.DataFrame()
    # 수집된 데이터를 Pandas 데이터 프레임 형식으로 변환

    for k in range(len(items)):
        df_raw = []
        for j in column_nm:
#             print(LAWD_CD_list[i],k,j) # 에러 파악 여부 
            try:
                items_data = items[k].find(j).text
                df_raw.append(items_data)
            except:
                items_data = "존재하지 않음"
                df_raw.append(items_data)
        df = pd.DataFrame(df_raw).T
        df.columns = column_nm
        
        total = pd.concat([total, df])

    total.columns = column_nm

# total.head().T

directory = "data/apt_trade"
if not os.path.exists(directory):
    os.makedirs(directory)
    
file_name = '../0_data/apt_trade/apt_trade_sample_' + '202101' + ".csv"
total.to_csv(file_name, index = False)
